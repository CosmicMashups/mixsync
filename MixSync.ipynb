# %% [markdown]
# # **MixSync: Song Key & BPM Finder**
# With this application, you can accurately find and sort songs by key and BPM,
# curated with meticulous verification, and filter them by various attributes for a seamless music-matching experience.

# %%
from google.colab import drive
drive.mount ('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# @title For Western Songs
import pandas as pd
import time

# Delay function for animation purposes
def delay():
    time.sleep(0.5)


# Check if input is numeric
def is_numeric(input_str):
    try:
        float(input_str)
        return True
    except ValueError:
        return False


# Sort database by specified column
def sorting(sort_column, sort_order):
    if sort_order.lower() == "Ascending":
        sorted_df = database.sort_values(by=sort_column)
    elif sort_order.lower() == "Descending":
        sorted_df = database.sort_values(by=sort_column, ascending=False)
    sorted_df.to_csv(db_name, index=False)
    return sorted_df


# Find songs within specified BPM range
def bpm_finder(database, bpm, bpm_thresh):
    delay()
    print(f"Finding songs that are ±{bpm_thresh} BPM around {bpm} BPM...")
    bpm_min = bpm - bpm_thresh
    bpm_max = bpm + bpm_thresh
    find_bpm = database[(database['BPM'].between(bpm_min, bpm_max))]
    return find_bpm


# Find songs within specified key range
def key_finder(find_bpm, key, key_thresh):
    delay()
    print(f"Finding songs that are {key_thresh} keys apart from {key}...")
    key_index = key_list.index(key)
    surrounding_keys = []
    for counter in range(-key_thresh, key_thresh + 1):
        if 0 <= key_index + counter < len(key_list):
            surrounding_keys.append(key_list[key_index + counter])
    find_keybpm = find_bpm[find_bpm['KEY'].isin(surrounding_keys)]
    return find_keybpm


# MAIN PROGRAM
if __name__ == "__main__":
  div = "=" * 15

  # List of keys
  key_list = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]

  # Read the database based on db_name
  db_name = 'westerndb.csv'
  database = pd.read_csv('/gdrive/My Drive/MixSync/westerndb.csv')
  columns_to_display = ['ARTIST', 'TITLE', 'KEY', 'BPM']
  pd.set_option('display.max_rows', None)
  pd.set_option('display.max_columns', None)

  # User input: BPM, Key, BPM and Key Threshold
  while True:
      try:
          # @markdown BPM: Beats per Minute
          bpm = 105 # @param {type:"slider", min:70, max:139, step:1}
          if bpm not in range(70, 140):
              raise ValueError("BPM must be between 70 and 139.")
          break
      except ValueError:
          print("Input is not a valid number or outside the range.")

  while True:
      # @markdown Key: The pitch around which the song revolves melodically
      key = "C" # @param ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]
      if key in key_list:
          break
      else:
          print("Input is not a valid key.")

  while True:
      try:
          # @markdown BPM Threshold:
          # @markdown The allowable deviation from the specified BPM to include other songs that have a BPM close to the specified value.
          bpm_thresh = 5 # @param {type:"slider", min:0, max:35, step:1}
          break
      except ValueError:
          print("Input is not a valid number.")

  while True:
      try:
          # @markdown Key Threshold:
          # @markdown The number of musical keys away from the specified key that you are willing to consider when searching for songs.
          key_thresh = 0 # @param {type:"slider", min:0, max:6, step:1}
          break
      except ValueError:
          print("Input is not a valid number.")

  # Adjust bpm and bpm_thresh if bpm is not in the range
  if bpm not in range(70, 140):
      bpm /= 2
      bpm_thresh /= 2

  # User input: Ask if the list needs to be sorted
  # @markdown Sort the list? or not?
  sort = "NO SORT" # @param ["NO SORT", "ARTIST", "TITLE", "KEY", "BPM"]
  sort_order = "Ascending" # @param ["Ascending", "Descending"]

  if sort == "NO SORT":
      sort_db = database  # Use the unsorted database
  else:
      sort_db = sorting(sort, sort_order)

  # Function calls: Find songs
  find_bpm = bpm_finder(sort_db, bpm, bpm_thresh)
  find_keybpm = key_finder(find_bpm, key, key_thresh)

  # Display results
  delay()
  print(f"{div} SONGS {div}")
  print(find_keybpm[columns_to_display])
  print(f"{div}======={div}")
# Out:
# Finding songs that are ±5 BPM around 105 BPM...
# Finding songs that are 0 keys apart from C...
# =============== SONGS ===============
#                         ARTIST                        TITLE KEY     BPM
# 1664              David Guetta            This Ones For You   C  110.00
# 1676             Justin Bieber               Get Used To It   C  110.00
# 1677              Taylor Swift             King Of My Heart   C  110.00
# 1680              Taylor Swift                      The Man   C  110.00
# 1686                     Adele             Love In The Dark   C  110.00
# 1687                   Allie X                      Vintage   C  110.00
# 1689                      ZAYN                         BLUE   C  110.00
# 1693                The Weeknd                      Secrets   C  110.00
# 1706  Selena Gomez & The Scene               Bang Bang Bang   C  110.00
# 1729               Nicki Minaj                    Hell Yeah   C  109.00
# 1735                 Dua Lipa                   No Goodbyes   C  109.00
# 1761            Skylar Stecker                   How Did We   C  108.00
# 1764                The Weeknd           Can't Feel My Face   C  108.00
# 1765               Major Lazer          Light It Up (Remix)   C  108.00
# 1767                  Dua Lipa               Not My Problem   C  108.00
# 1768                      fun.                  Some Nights   C  108.00
# 1769           Imagine Dragons          Nothing Left To Say   C  108.00
# 1771                   Allie X             Girl Of The Year   C  108.00
# 1781            Britney Spears                     Criminal   C  108.00
# 1784              David Guetta                 Bang My Head   C  108.00
# 1793                   Zendaya             Love You Forever   C  107.00
# 1794             Rina Sawayama                 Love Me 4 Me   C  107.00
# 1819                   Allie X                    Sanctuary   C  106.00
# 1831              Taylor Swift           We Were Happy (TV)   C  106.00
# 1834                       BTS                           ON   C  106.00
# 1838                    MARINA                   Obsessions   C  105.00
# 1840                 Dua Lipa                        Dreams   C  105.00
# 1841              Harry Styles              To Be So Lonely   C  105.00
# 1848           Imagine Dragons                   West Coast   C  105.00
# 1872            Natalie LaRose                     Somebody   C  105.00
# 1876                Bruno Mars                    Moonshine   C  105.00
# 1879               Troye SIvan                    THE QUIET   C  104.00
# 1885              Taylor Swift       Soon You'll Get Better   C  104.00
# 1890                    AURORA  Murder Song (5, 4, 3, 2, 1)   C  104.00
# 1891             Fifth Harmony                     The Life   C  104.00
# 1911                  Flo Rida                      Whistle   C  104.00
# 1915         Mark Mothersbaugh           Rugrats Theme Song   C  103.05
# 1943            Ellie Goulding        Anything Could Happen   C  103.00
# 1951                   Finneas                    Die Alone   C  102.60
# 1954                 Sean Paul                       No Lie   C  102.00
# 1955                 Dua Lipa                        No Lie   C  102.00
# 1956              Clean Bandit                     Rockabye   C  102.00
# 1974              Taylor Swift              Cornelia Street   C  102.00
# 1987                   Tove Lo                    Cool Girl   C  102.00
# 1995           Imagine Dragons                  Working Man   C  101.00
# 2000             Ariana Grande                       Only 1   C  101.00
# 2003                  The 1975                Somebody Else   C  101.00
# 2008             Ariana Grande                Off The Table   C  101.00
# 2029                     BØRNS         Rolling In The Roses   C  100.00
# 2032                    Halsey                Good Mourning   C  100.00
# 2040               Major Lazer                     Sua Cara   C  100.00
# 2074                     Kygo                   It Ain't Me   C  100.00
# 2098           Imagine Dragons          On Top Of The World   C  100.00
# 2126                 Lady Gaga                  Bloody Mary   C  100.00
# 2127                  Maroon 5                         Cold   C  100.00
# 2137               Niall Horan                   Small Talk   C  100.00
# 2138              Taylor Swift               Stay Stay Stay   C  100.00
# 2139             Billie Eilish           listen before i go   C  100.00
# 2141                 Lady Gaga         So Happy I Could Die   C  100.00
# =====================================

# %%
# @title For Anime Songs
import pandas as pd
import time

# Delay function for animation purposes
def delay():
    time.sleep(0.5)


# Check if input is numeric
def is_numeric(input_str):
    try:
        float(input_str)
        return True
    except ValueError:
        return False


# Sort database by specified column
def sorting(sort_column, sort_order):
    if sort_order.lower() == "Ascending":
        sorted_df = database.sort_values(by=sort_column)
    elif sort_order.lower() == "Descending":
        sorted_df = database.sort_values(by=sort_column, ascending=False)
    sorted_df.to_csv(db_name, index=False)
    return sorted_df


# Find songs within specified BPM range
def bpm_finder(database, bpm, bpm_thresh):
    delay()
    print(f"Finding songs that are ±{bpm_thresh} BPM around {bpm} BPM...")
    bpm_min = bpm - bpm_thresh
    bpm_max = bpm + bpm_thresh
    find_bpm = database[(database['BPM'].between(bpm_min, bpm_max))]
    return find_bpm


# Find songs within specified key range
def key_finder(find_bpm, key, key_thresh):
    delay()
    print(f"Finding songs that are {key_thresh} keys apart from {key}...")
    key_index = key_list.index(key)
    surrounding_keys = []
    for counter in range(-key_thresh, key_thresh + 1):
        if 0 <= key_index + counter < len(key_list):
            surrounding_keys.append(key_list[key_index + counter])
    find_keybpm = find_bpm[find_bpm['KEY'].isin(surrounding_keys)]
    return find_keybpm


# MAIN PROGRAM
if __name__ == "__main__":
  div = "=" * 15

  # List of keys
  key_list = ["C Major", "C# Major", "D Major", "D# Major", "E Major", "F Major",
              "F# Major", "G Major", "G# Major", "A Major", "A# Major", "B Major"]

  # Read the database based on db_name
  db_name = 'keybpm.csv'
  database = pd.read_csv('/gdrive/My Drive/MixSync/keybpm.csv')
  columns_to_display = ['BPM', 'TITLE', 'KEY', 'YEAR']
  pd.set_option('display.max_rows', None)
  pd.set_option('display.max_columns', None)

  # User input: BPM, Key, BPM and Key Threshold
  while True:
      try:
          # @markdown BPM: Beats per Minute
          bpm = 74 # @param {type:"slider", min:70, max:139, step:1}
          if bpm not in range(70, 140):
              raise ValueError("BPM must be between 70 and 139.")
          break
      except ValueError:
          print("Input is not a valid number or outside the range.")

  while True:
      # @markdown Key: The pitch around which the song revolves melodically
      key = "C Major" # @param ["C Major", "C# Major", "D Major", "D# Major", "E Major", "F Major", "F# Major", "G Major", "G# Major", "A Major", "A# Major", "B Major"]
      if key in key_list:
          break
      else:
          print("Input is not a valid key.")

  while True:
      try:
          # @markdown BPM Threshold:
          # @markdown The allowable deviation from the specified BPM to include other songs that have a BPM close to the specified value.
          bpm_thresh = 3 # @param {type:"slider", min:0, max:35, step:1}
          break
      except ValueError:
          print("Input is not a valid number.")

  while True:
      try:
          # @markdown Key Threshold:
          # @markdown The number of musical keys away from the specified key that you are willing to consider when searching for songs.
          key_thresh = 0 # @param {type:"slider", min:0, max:6, step:1}
          break
      except ValueError:
          print("Input is not a valid number.")

  # Adjust bpm and bpm_thresh if bpm is not in the range
  if bpm not in range(70, 140):
      bpm /= 2
      bpm_thresh /= 2

  # User input: Ask if the list needs to be sorted
  # @markdown Sort the list? or not?
  sort = "NO SORT" # @param ["NO SORT", "ARTIST", "TITLE", "KEY", "BPM"]
  sort_order = "Ascending" # @param ["Ascending", "Descending"]

  if sort == "NO SORT":
      sort_db = database  # Use the unsorted database
  else:
      sort_db = sorting(sort, sort_order)

  # Function calls: Find songs
  find_bpm = bpm_finder(sort_db, bpm, bpm_thresh)
  find_keybpm = key_finder(find_bpm, key, key_thresh)

  # Display results
  delay()
  print(f"{div} SONGS {div}")
  print(find_keybpm[columns_to_display])
  print(f"{div}======={div}")
# Out:
# Finding songs that are ±3 BPM around 74 BPM...
# Finding songs that are 0 keys apart from C Major...
# =============== SONGS ===============
#      BPM               TITLE      KEY  YEAR
# 22  71.5             Ryuusei  C Major  2018
# 41  74.0      Isekai Quartet  C Major  2019
# 48  75.0         Bravely You  C Major  2015
# 55  75.5  B Chiku Sentai SOX  C Major  2015
# =====================================
